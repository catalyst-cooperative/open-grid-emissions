# %% [markdown]
# # Test part of data pipeline where we merge all the hourly data
#
# Breaks on full run: need to convert to dask df

# %%
import pandas as pd
import numpy as np
import dask.dataframe as dd

# %%
# Start client so can see worker mem use
from dask.distributed import Client 
client = Client(n_workers=2, threads_per_worker=2, memory_limit="1GB") # limit worker size to create issues even on --small dataset
client
# Out:
# /Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/node.py:180: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 52231 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:52235' processes=2 threads=4, memory=1.86 GiB>

# %%
# %reload_ext autoreload
# %autoreload 2

# # Tell python where to look for modules.
import sys

sys.path.append("../../hourly-egrid/")

# import local modules
import src.data_cleaning as data_cleaning

# %%
o_shaped_eia_data = pd.read_csv("../data/outputs/small/shaped_eia923_data_2020.csv", parse_dates=["datetime_utc"])
o_partial_cems_scaled = pd.read_csv("../data/outputs/small/partial_cems_scaled_2020.csv", parse_dates=["datetime_utc"]) #NOT FINAL VERSION 
o_cems = pd.read_csv("../data/outputs/small/cems_2020.csv", parse_dates=["datetime_utc"]) # NOT FINAL VERSION

# shaped_eia_data = pd.read_csv("../data/outputs/shaped_eia923_data_2020.csv")
# partial_cems_scaled = pd.read_csv("../data/outputs/partial_cems_scaled_2020.csv") #NOT FINAL VERSION 
# cems = pd.read_csv("../data/outputs/cems_2020.csv") # NOT FINAL VERSION
# Out:
# /var/folders/mr/3dcnnc3153j6s05bmdwr0r0h0000gq/T/ipykernel_66126/3263455066.py:3: DtypeWarning: Columns (1,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   o_cems = pd.read_csv("../data/outputs/small/cems_2020.csv", parse_dates=["datetime_utc"]) # NOT FINAL VERSION

# %%
# most of the stuff done to partial_cems_scaled and cems in data_pipeline is in plant_static_attributes: 
#plant_static_attributes = pd.read_csv("../data/results/plant_data/plant_static_attributes.csv")

plant_static_attributes = pd.read_csv("../data/results/small/plant_data/plant_static_attributes.csv")

# %%
o_partial_cems_scaled = o_partial_cems_scaled.merge(plant_static_attributes, how='left', on='plant_id_eia')
o_cems = o_cems.merge(plant_static_attributes, how='left', on='plant_id_eia')

# %%
# Problem data_pipeline steps: on small data, these are fine with worker size 16GB (break with worker size 1GB)
# On full dataset, these break with worker size 16GB (ie Gailin's laptop)

combined_plant_data = data_cleaning.combine_subplant_data(
        o_cems, o_partial_cems_scaled, o_shaped_eia_data
)

# # 12. Aggregate CEMS data to BA-fuel and write power sector results
# ba_fuel_data = data_cleaning.aggregate_plant_data_to_ba_fuel(
#     combined_plant_data, plant_static_attributes
# )
# Out:
# Dask Index Structure:
# npartitions=2000
# 2020-01-01 05:00:00+00:00    datetime64[ns, UTC]
# 2020-01-01 11:00:00+00:00                    ...
#                                     ...
# 2021-01-01 05:00:00+00:00                    ...
# 2021-01-01 07:00:00+00:00                    ...
# Name: datetime_utc, dtype: datetime64[ns, UTC]
# Dask Name: from_pandas, 4000 tasks
#
# Dask Index Structure:
# npartitions=1
#     datetime64[ns]
#                ...
# Name: datetime_utc, dtype: datetime64[ns]
# Dask Name: from_pandas, 2 tasks
#
# Dask Index Structure:
# npartitions=2000
# 2020-01-01 05:00:00+00:00    datetime64[ns, UTC]
# 2020-01-01 11:00:00+00:00                    ...
#                                     ...
# 2021-01-01 03:00:00+00:00                    ...
# NaT                                          ...
# Name: datetime_utc, dtype: datetime64[ns, UTC]
# Dask Name: from_pandas, 4000 tasks
#
# plant_id_eia                                    int64
# subplant_id                                     int64
# report_date                            datetime64[ns]
# data_source                                  category
# hourly_profile_source                        category
# gross_generation_mwh                          float64
# net_generation_mwh                            float64
# net_generation_method                        category
# steam_load_1000_lb                            float64
# fuel_consumed_mmbtu                           float64
# fuel_consumed_for_electricity_mmbtu           float64
# co2_mass_lb                                   float64
# ch4_mass_lb                                   float64
# n2o_mass_lb                                   float64
# nox_mass_lb                                   float64
# so2_mass_lb                                   float64
# co2_mass_lb_for_electricity                   float64
# ch4_mass_lb_for_electricity                   float64
# n2o_mass_lb_for_electricity                   float64
# nox_mass_lb_for_electricity                   float64
# so2_mass_lb_for_electricity                   float64
# co2_mass_lb_adjusted                          float64
# ch4_mass_lb_adjusted                          float64
# n2o_mass_lb_adjusted                          float64
# nox_mass_lb_adjusted                          float64
# so2_mass_lb_adjusted                          float64
# dtype: object

# %%
combined_plant_data.groupby("datetime_utc").sum().compute()
# Out:
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 713.42 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Worker is at 92% memory usage. Pausing worker.  Process memory: 882.38 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 882.38 MiB -- Worker memory limit: 0.93 GiB
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 745.55 MiB -- Worker memory limit: 0.93 GiB
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 700.67 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Worker is at 88% memory usage. Pausing worker.  Process memory: 845.41 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 845.41 MiB -- Worker memory limit: 0.93 GiB
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 687.20 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 777.89 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 777.89 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Worker is at 72% memory usage. Resuming worker. Process memory: 689.00 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 689.00 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 763.03 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 763.03 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 831.59 MiB -- Worker memory limit: 0.93 GiB
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# ---------------------------------------------------------------------------
# KilledWorker                              Traceback (most recent call last)
# /Users/gailin.pease/singularity/hourly-egrid/notebooks/test_dask.ipynb Cell 22' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/gailin.pease/singularity/hourly-egrid/notebooks/test_dask.ipynb#ch0000021?line=0'>1</a> combined_plant_data.groupby("datetime_utc").sum().compute()
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py:290, in DaskMethodsMixin.compute(self, **kwargs)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=265'>266</a> def compute(self, **kwargs):
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=266'>267</a>     """Compute this dask collection
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=267'>268</a>
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=268'>269</a>     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=287'>288</a>     dask.base.compute
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=288'>289</a>     """
# --> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=289'>290</a>     (result,) = compute(self, traverse=False, **kwargs)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=290'>291</a>     return result
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py:573, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=569'>570</a>     keys.append(x.__dask_keys__())
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=570'>571</a>     postcomputes.append(x.__dask_postcompute__())
# --> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=572'>573</a> results = schedule(dsk, keys, **kwargs)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=573'>574</a> return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py:3010, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=3007'>3008</a>         should_rejoin = False
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=3008'>3009</a> try:
# -> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=3009'>3010</a>     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=3010'>3011</a> finally:
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=3011'>3012</a>     for f in futures.values():
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py:2162, in Client.gather(self, futures, errors, direct, asynchronous)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2159'>2160</a> else:
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2160'>2161</a>     local_worker = None
# -> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2161'>2162</a> return self.sync(
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2162'>2163</a>     self._gather,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2163'>2164</a>     futures,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2164'>2165</a>     errors=errors,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2165'>2166</a>     direct=direct,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2166'>2167</a>     local_worker=local_worker,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2167'>2168</a>     asynchronous=asynchronous,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2168'>2169</a> )
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py:311, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=308'>309</a>     return future
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=309'>310</a> else:
# --> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=310'>311</a>     return sync(
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=311'>312</a>         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=312'>313</a>     )
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py:378, in sync(loop, func, callback_timeout, *args, **kwargs)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=375'>376</a> if error:
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=376'>377</a>     typ, exc, tb = error
# --> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=377'>378</a>     raise exc.with_traceback(tb)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=378'>379</a> else:
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=379'>380</a>     return result
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py:351, in sync.<locals>.f()
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=348'>349</a>         future = asyncio.wait_for(future, callback_timeout)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=349'>350</a>     future = asyncio.ensure_future(future)
# --> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=350'>351</a>     result = yield future
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=351'>352</a> except Exception:
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=352'>353</a>     error = sys.exc_info()
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/tornado/gen.py:762, in Runner.run(self)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/tornado/gen.py?line=758'>759</a> exc_info = None
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/tornado/gen.py?line=760'>761</a> try:
# --> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/tornado/gen.py?line=761'>762</a>     value = future.result()
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/tornado/gen.py?line=762'>763</a> except Exception:
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/tornado/gen.py?line=763'>764</a>     exc_info = sys.exc_info()
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py:2025, in Client._gather(self, futures, errors, direct, local_worker)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2022'>2023</a>         exc = CancelledError(key)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2023'>2024</a>     else:
# -> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2024'>2025</a>         raise exception.with_traceback(traceback)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2025'>2026</a>     raise exc
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2026'>2027</a> if errors == "skip":
#
# KilledWorker: ("('from_pandas-ef151113b7b1d10ba6a05d54644e5757', 1760)", <WorkerState 'tcp://127.0.0.1:60150', name: 1, status: closed, memory: 0, processing: 4001>)
# distributed.nanny - WARNING - Restarting worker

# %%
indexed_plants = plant_static_attributes.set_index("plant_id_eia")

# %%
indexed_plants
# Out:
#              plant_primary_fuel fuel_category fuel_category_eia930 ba_code ba_code_physical state  distribution_flag             timezone
# plant_id_eia
# 4                           WAT         hydro                hydro    SOCO             SOCO    AL              False      America/Chicago
# 62                          WAT         hydro                hydro     NaN              NaN    AK               True       America/Juneau
# 64                          DFO     petroleum            petroleum     NaN              NaN    AK              False       America/Juneau
# 70                          WAT         hydro                hydro     NaN              NaN    AK              False    America/Anchorage
# 193                         DFO     petroleum            petroleum     SPA              SPA    AR              False      America/Chicago
# ...                         ...           ...                  ...     ...              ...   ...                ...                  ...
# 63961                       SUN         solar                solar     PGE              PGE    OR               True  America/Los_Angeles
# 64211                       SUN         solar                solar    SOCO             SOCO    GA               True     America/New_York
# 64221                       SUN         solar                solar    CISO             CISO    CA               True  America/Los_Angeles
# 64298                       MWH         other                other    ERCO             ERCO    TX               True      America/Chicago
# 64330                       SUN         solar                solar     PJM              PJM    IL               True      America/Chicago
#
# [518 rows x 8 columns]

# %%
dtypes = partial.dtypes.to_dict()
dtypes["new_ba_code"] = str

# %%
partial_new = partial.map_partitions(lambda df: df.assign(new_ba_code=indexed_plants.loc[df.plant_id_eia,"ba_code"]),
    meta=dtypes)

# %%
partial.compute()
# Out:
# Empty DataFrame
# Columns: [report_date, subplant_id, fuel_consumed_mmbtu, fuel_consumed_for_electricity_mmbtu, net_generation_mwh, co2_mass_lb, ch4_mass_lb, n2o_mass_lb, nox_mass_lb, so2_mass_lb, co2_mass_lb_for_electricity, ch4_mass_lb_for_electricity, n2o_mass_lb_for_electricity, nox_mass_lb_for_electricity, so2_mass_lb_for_electricity, co2_mass_lb_adjusted, ch4_mass_lb_adjusted, n2o_mass_lb_adjusted, nox_mass_lb_adjusted, so2_mass_lb_adjusted, plant_id_eia, plant_primary_fuel, fuel_category, fuel_category_eia930, ba_code, ba_code_physical, state, distribution_flag, timezone]
# Index: []

# %%
partial = dd.from_pandas(o_partial_cems_scaled.astype({"datetime_utc":"datetime64"}).set_index("datetime_utc"), npartitions=20)
cems = dd.from_pandas(o_cems.set_index("datetime_utc"), npartitions=20)

# %%
partial
# Out:
# Dask DataFrame Structure:
#               report_date subplant_id fuel_consumed_mmbtu fuel_consumed_for_electricity_mmbtu net_generation_mwh co2_mass_lb ch4_mass_lb n2o_mass_lb nox_mass_lb so2_mass_lb co2_mass_lb_for_electricity ch4_mass_lb_for_electricity n2o_mass_lb_for_electricity nox_mass_lb_for_electricity so2_mass_lb_for_electricity co2_mass_lb_adjusted ch4_mass_lb_adjusted n2o_mass_lb_adjusted nox_mass_lb_adjusted so2_mass_lb_adjusted plant_id_eia plant_primary_fuel fuel_category fuel_category_eia930 ba_code ba_code_physical   state distribution_flag timezone
# npartitions=1
#                    object      object              object                              object             object      object      object      object      object      object                      object                      object                      object                      object                      object               object               object               object               object               object        int64             object        object               object  object           object  object              bool   object
#                       ...         ...                 ...                                 ...                ...         ...         ...         ...         ...         ...                         ...                         ...                         ...                         ...                         ...                  ...                  ...                  ...                  ...                  ...          ...                ...           ...                  ...     ...              ...     ...               ...      ...
# Dask Name: from_pandas, 1 tasks

# %%
cems = cems[cems.index.dropna()]

# %%
#partial = partial[partial.index.dropna()]

# %%
combined = dd.concat([partial, cems], axis=0)

# %%
combined.index = combined.index.astype("datetime64[ns]")

# %%
partial.group
# Out:
# Dask DataFrame Structure:
#               report_date subplant_id fuel_consumed_mmbtu fuel_consumed_for_electricity_mmbtu net_generation_mwh co2_mass_lb ch4_mass_lb n2o_mass_lb nox_mass_lb so2_mass_lb co2_mass_lb_for_electricity ch4_mass_lb_for_electricity n2o_mass_lb_for_electricity nox_mass_lb_for_electricity so2_mass_lb_for_electricity co2_mass_lb_adjusted ch4_mass_lb_adjusted n2o_mass_lb_adjusted nox_mass_lb_adjusted so2_mass_lb_adjusted plant_id_eia plant_primary_fuel fuel_category fuel_category_eia930 ba_code ba_code_physical   state distribution_flag timezone
# npartitions=1
#                    object      object              object                              object             object      object      object      object      object      object                      object                      object                      object                      object                      object               object               object               object               object               object        int64             object        object               object  object           object  object              bool   object
#                       ...         ...                 ...                                 ...                ...         ...         ...         ...         ...         ...                         ...                         ...                         ...                         ...                         ...                  ...                  ...                  ...                  ...                  ...          ...                ...           ...                  ...     ...              ...     ...               ...      ...
# Dask Name: from_pandas, 1 tasks

# %%
out = partial.groupby(["datetime_utc","ba_code"], dropna=False, sort=False, group_keys=False).sum()

# %%
out.set_index("datetime_utc")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'datetime_utc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [137], in <cell line: 1>()
# ----> 1 out.set_index("datetime_utc")
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py:4609, in DataFrame.set_index(***failed resolving arguments***)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py?line=4605'>4606</a> else:
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py?line=4606'>4607</a>     from .shuffle import set_index
# -> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py?line=4608'>4609</a>     return set_index(
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py?line=4609'>4610</a>         self,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py?line=4610'>4611</a>         other,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py?line=4611'>4612</a>         drop=drop,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py?line=4612'>4613</a>         npartitions=npartitions,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py?line=4613'>4614</a>         divisions=divisions,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py?line=4614'>4615</a>         **kwargs,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py?line=4615'>4616</a>     )
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/shuffle.py:210, in set_index(df, index, npartitions, shuffle, compute, drop, upsample, divisions, partition_size, **kwargs)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/shuffle.py?line=206'>207</a>     repartition = False
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/shuffle.py?line=208'>209</a> if not isinstance(index, Series):
# --> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/shuffle.py?line=209'>210</a>     index2 = df[index]
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/shuffle.py?line=210'>211</a> else:
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/shuffle.py?line=211'>212</a>     index2 = index
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py:4285, in DataFrame.__getitem__(self, key)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py?line=4281'>4282</a>         return self.loc[key]
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py?line=4283'>4284</a> # error is raised from pandas
# -> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py?line=4284'>4285</a> meta = self._meta[_extract_meta(key)]
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py?line=4285'>4286</a> dsk = partitionwise_graph(operator.getitem, name, self, key)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/dataframe/core.py?line=4286'>4287</a> graph = HighLevelGraph.from_collections(name, dsk, dependencies=[self])
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'datetime_utc'

# %% [markdown]
# # What is the minimum dataset for which this breaks?

# %%
o_shaped_eia_data.columns
# Out:
# Index(['plant_id_eia', 'subplant_id', 'datetime_local', 'datetime_utc', 'report_date', 'net_generation_mwh', 'fuel_consumed_mmbtu', 'fuel_consumed_for_electricity_mmbtu', 'co2_mass_lb', 'ch4_mass_lb', 'n2o_mass_lb', 'nox_mass_lb', 'so2_mass_lb', 'co2_mass_lb_for_electricity', 'ch4_mass_lb_for_electricity', 'n2o_mass_lb_for_electricity', 'nox_mass_lb_for_electricity', 'so2_mass_lb_for_electricity', 'co2_mass_lb_adjusted', 'ch4_mass_lb_adjusted', 'n2o_mass_lb_adjusted', 'nox_mass_lb_adjusted', 'so2_mass_lb_adjusted', 'profile_method', 'hourly_data_source'], dtype='object')

# %%
o_shaped_eia_data.datetime_utc = pd.to_datetime(o_shaped_eia_data.datetime_utc)

# %%
#dt_shaped["datetime_utc"] = dt_shaped.datetime_utc.dt.to_datetime64()

# %%
dt_shaped = o_shaped_eia_data.set_index("datetime_utc")
shaped_eia_dask = dd.from_pandas(dt_shaped, npartitions=50)

# %%
o_partial_cems_scaled
# Out:
# Empty DataFrame
# Columns: [report_date, subplant_id, datetime_utc, fuel_consumed_mmbtu, fuel_consumed_for_electricity_mmbtu, net_generation_mwh, co2_mass_lb, ch4_mass_lb, n2o_mass_lb, nox_mass_lb, so2_mass_lb, co2_mass_lb_for_electricity, ch4_mass_lb_for_electricity, n2o_mass_lb_for_electricity, nox_mass_lb_for_electricity, so2_mass_lb_for_electricity, co2_mass_lb_adjusted, ch4_mass_lb_adjusted, n2o_mass_lb_adjusted, nox_mass_lb_adjusted, so2_mass_lb_adjusted, plant_id_eia, plant_primary_fuel, fuel_category, fuel_category_eia930, ba_code, ba_code_physical, state, distribution_flag, timezone]
# Index: []

# %%
shaped_eia_dask
# Out:
# Dask DataFrame Structure:
#                           plant_id_eia subplant_id datetime_local report_date net_generation_mwh fuel_consumed_mmbtu fuel_consumed_for_electricity_mmbtu co2_mass_lb ch4_mass_lb n2o_mass_lb nox_mass_lb so2_mass_lb co2_mass_lb_for_electricity ch4_mass_lb_for_electricity n2o_mass_lb_for_electricity nox_mass_lb_for_electricity so2_mass_lb_for_electricity co2_mass_lb_adjusted ch4_mass_lb_adjusted n2o_mass_lb_adjusted nox_mass_lb_adjusted so2_mass_lb_adjusted profile_method hourly_data_source
# npartitions=50
# 2020-01-01 05:00:00+00:00        int64     float64         object      object            float64             float64                             float64     float64     float64     float64     float64     float64                     float64                     float64                     float64                     float64                     float64              float64              float64              float64              float64              float64         object             object
# 2020-01-08 17:00:00+00:00          ...         ...            ...         ...                ...                 ...                                 ...         ...         ...         ...         ...         ...                         ...                         ...                         ...                         ...                         ...                  ...                  ...                  ...                  ...                  ...            ...                ...
# ...                                ...         ...            ...         ...                ...                 ...                                 ...         ...         ...         ...         ...         ...                         ...                         ...                         ...                         ...                         ...                  ...                  ...                  ...                  ...                  ...            ...                ...
# 2020-12-25 04:00:00+00:00          ...         ...            ...         ...                ...                 ...                                 ...         ...         ...         ...         ...         ...                         ...                         ...                         ...                         ...                         ...                  ...                  ...                  ...                  ...                  ...            ...                ...
# NaT                                ...         ...            ...         ...                ...                 ...                                 ...         ...         ...         ...         ...         ...                         ...                         ...                         ...                         ...                         ...                  ...                  ...                  ...                  ...                  ...            ...                ...
# Dask Name: from_pandas, 50 tasks

# %%
smol = shaped_eia_dask[["net_generation_mwh","fuel_consumed_mmbtu"]]

# %%
smol["2020/01/20T00:00"]
# Out:
# Dask DataFrame Structure:
#                                     net_generation_mwh fuel_consumed_mmbtu
# npartitions=1
# 2020-01-20 00:00:00+00:00                      float64             float64
# 2020-01-20 00:00:59.999999999+00:00                ...                 ...
# Dask Name: loc, 101 tasks

# %%
# even this breaks. If can get this to work, maybe that solution works for rest? 
smol.groupby("datetime_utc").sum().compute()
# Out:
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 736.12 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 735.70 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 794.69 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 685.12 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 676.39 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 847.84 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 845.88 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 837.53 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 687.25 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 777.66 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 795.69 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 814.34 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 814.34 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 768.16 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 814.20 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Worker is at 78% memory usage. Resuming worker. Process memory: 750.17 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 750.17 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 797.98 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Worker is at 109% memory usage. Pausing worker.  Process memory: 1.02 GiB -- Worker memory limit: 0.93 GiB
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 779.97 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 779.98 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 779.98 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 779.98 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 779.98 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 780.00 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 733.52 MiB -- Worker memory limit: 0.93 GiB
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 775.09 MiB -- Worker memory limit: 0.93 GiB
# distributed.nanny - WARNING - Restarting worker
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 775.09 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 775.09 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 775.11 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 775.11 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Worker is at 74% memory usage. Resuming worker. Process memory: 714.08 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 714.08 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 701.38 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 759.14 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Worker is at 87% memory usage. Pausing worker.  Process memory: 831.41 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 852.81 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 860.91 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 807.64 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Worker is at 72% memory usage. Resuming worker. Process memory: 695.22 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 695.22 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 730.50 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 713.66 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 760.59 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Worker is at 94% memory usage. Pausing worker.  Process memory: 900.44 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 894.89 MiB -- Worker memory limit: 0.93 GiB
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:61838
# Traceback (most recent call last):
#   File "/Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/tornado/iostream.py", line 867, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#   File "/Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/tornado/iostream.py", line 1140, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/worker.py", line 3100, in gather_dep
#     response = await get_data_from_worker(
#   File "/Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/worker.py", line 4415, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils_comm.py", line 386, in retry_operation
#     return await retry(
#   File "/Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils_comm.py", line 371, in retry
#     return await coro()
#   File "/Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/worker.py", line 4395, in _get_data
#     response = await send_recv(
#   File "/Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/core.py", line 691, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/comm/tcp.py", line 227, in read
#     convert_stream_closed_error(self, e)
#   File "/Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/comm/tcp.py", line 133, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:53658 remote=tcp://127.0.0.1:61838>: ConnectionResetError: [Errno 54] Connection reset by peer
# distributed.worker - WARNING - Worker is at 87% memory usage. Pausing worker.  Process memory: 830.41 MiB -- Worker memory limit: 0.93 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 830.41 MiB -- Worker memory limit: 0.93 GiB
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# ---------------------------------------------------------------------------
# KilledWorker                              Traceback (most recent call last)
# Input In [87], in <cell line: 2>()
#       1 # even this breaks. If can get this to work, maybe that solution works for rest?
# ----> 2 smol.groupby("datetime_utc").sum().compute()
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py:290, in DaskMethodsMixin.compute(self, **kwargs)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=265'>266</a> def compute(self, **kwargs):
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=266'>267</a>     """Compute this dask collection
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=267'>268</a>
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=268'>269</a>     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=287'>288</a>     dask.base.compute
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=288'>289</a>     """
# --> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=289'>290</a>     (result,) = compute(self, traverse=False, **kwargs)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=290'>291</a>     return result
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py:573, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=569'>570</a>     keys.append(x.__dask_keys__())
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=570'>571</a>     postcomputes.append(x.__dask_postcompute__())
# --> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=572'>573</a> results = schedule(dsk, keys, **kwargs)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/dask/base.py?line=573'>574</a> return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py:3010, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=3007'>3008</a>         should_rejoin = False
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=3008'>3009</a> try:
# -> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=3009'>3010</a>     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=3010'>3011</a> finally:
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=3011'>3012</a>     for f in futures.values():
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py:2162, in Client.gather(self, futures, errors, direct, asynchronous)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2159'>2160</a> else:
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2160'>2161</a>     local_worker = None
# -> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2161'>2162</a> return self.sync(
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2162'>2163</a>     self._gather,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2163'>2164</a>     futures,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2164'>2165</a>     errors=errors,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2165'>2166</a>     direct=direct,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2166'>2167</a>     local_worker=local_worker,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2167'>2168</a>     asynchronous=asynchronous,
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2168'>2169</a> )
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py:311, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=308'>309</a>     return future
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=309'>310</a> else:
# --> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=310'>311</a>     return sync(
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=311'>312</a>         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=312'>313</a>     )
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py:378, in sync(loop, func, callback_timeout, *args, **kwargs)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=375'>376</a> if error:
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=376'>377</a>     typ, exc, tb = error
# --> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=377'>378</a>     raise exc.with_traceback(tb)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=378'>379</a> else:
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=379'>380</a>     return result
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py:351, in sync.<locals>.f()
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=348'>349</a>         future = asyncio.wait_for(future, callback_timeout)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=349'>350</a>     future = asyncio.ensure_future(future)
# --> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=350'>351</a>     result = yield future
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=351'>352</a> except Exception:
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/utils.py?line=352'>353</a>     error = sys.exc_info()
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/tornado/gen.py:762, in Runner.run(self)
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/tornado/gen.py?line=758'>759</a> exc_info = None
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/tornado/gen.py?line=760'>761</a> try:
# --> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/tornado/gen.py?line=761'>762</a>     value = future.result()
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/tornado/gen.py?line=762'>763</a> except Exception:
#     <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/tornado/gen.py?line=763'>764</a>     exc_info = sys.exc_info()
#
# File ~/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py:2025, in Client._gather(self, futures, errors, direct, local_worker)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2022'>2023</a>         exc = CancelledError(key)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2023'>2024</a>     else:
# -> <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2024'>2025</a>         raise exception.with_traceback(traceback)
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2025'>2026</a>     raise exc
#    <a href='file:///Users/gailin.pease/miniconda3/envs/hourly_egrid/lib/python3.9/site-packages/distributed/client.py?line=2026'>2027</a> if errors == "skip":
#
# KilledWorker: ("('from_pandas-0a0fcc79d26224c4f0b45f484386384f', 27)", <WorkerState 'tcp://127.0.0.1:53453', name: 1, status: closed, memory: 0, processing: 44>)
